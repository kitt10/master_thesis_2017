# %%
from kitt_net import FeedForwardNet
from shelve import open as open_shelve
from sklearn.metrics import confusion_matrix, accuracy_score
from matplotlib import pyplot as plt
# %matplotlib qt
from numpy import newaxis, delete, zeros, concatenate, unique, argmax

# %%
net = FeedForwardNet(hidden=[], tf_name='Sigmoid')
#net2 = FeedForwardNet(hidden=[], tf_name='Sigmoid')
#net_uu = FeedForwardNet(hidden=[], tf_name='Sigmoid')

# %%
net.load('../examples/mnist/net_mnist.net')
#net2.load('../examples/speech/net_speech_5000_A+a+Y.net')
#net_uu.load('../examples/speech/net_speech_5000_U+u.net')

# %%
dataset = open_shelve('../examples/mnist/dataset_mnist.ds', 'c')
#dataset_re = open_shelve('../examples/speech/dataset_speech_500_r+e.ds', 'c')
#dataset_aa = open_shelve('../examples/speech/dataset_speech_500_A+a.ds', 'c')

# %%
#net.fit(x=dataset['x'], y=dataset['y'], x_val=dataset['x_val'], y_val=dataset['y_val'], learning_rate=0.03, n_epoch=50, req_acc=1.0, batch_size=10) # speech
#net_sz.fit(x=dataset_sz['x'], y=dataset_sz['y'], x_val=dataset_sz['x_val'], y_val=dataset_sz['y_val'], learning_rate=0.03, n_epoch=50, req_acc=1.0, batch_size=1) # speech
#net_aa.fit(x=dataset_aa['x'], y=dataset_aa['y'], x_val=dataset_aa['x_val'], y_val=dataset_aa['y_val'], learning_rate=0.03, n_epoch=50, req_acc=1.0, batch_size=1)
# Out:
# --------------------------------------------------------------------
# -- Network initialized.
# 	% problem dimension: 440
# 	% number of classes: 4
# 	% class labels: [u'A', u'a', u's', u'z']
# 	% net structure: [440, 25, 4]
# 	% net transfer function: Sigmoid
#
# --------------------------------------------------------------------
# -- Learning has started...
# 	% problem dimension: 440
# 	% number of training samples: 16000
# 	% number of validation samples: 2000
# 	% learning rate: 0.03
# 	% mini-batch size: 10
# 	% maximum number of epochs (t.c.): 50
# 	% maximum number of stable epochs (t.c.): inf
# 	% required accuracy (t.c.): 1.0
# 	% required error (t.c.): -inf
#
#
# epoch   on training data      on validation data       epoch time
# -------------------------------------------------------------------
#  1	  0.75/0.0443		0.74/0.0435		1.7070 s
#  2	  0.78/0.0395		0.77/0.0391		1.6989 s
#  3	  0.80/0.0366		0.79/0.0368		1.9259 s
#  4	  0.81/0.0353		0.80/0.0362		1.8825 s
# ...

# %%
#net.prune(req_acc=0.89, req_err=0.05, n_epoch=5, levels=(75, 50, 30, 20, 10, 5, 3, 1, 0), verbose_learning=True)
# Out:
# --------------------------------------------------------------------
# -- Pruning has started...
# 	% net initial structure: [440, 25, 4]
# 	% net initial number of synapses (w, b): (11100, 29)
# 	% min required accuracy (s.c.): 0.89
# 	% max required error (s.c.): 0.05
# 	% maximum number of re-training epochs (gu.c.): 5
# 	% number of stable iterations (gu.c.): 10
#
#
# step    trying to cut     structure           left synapses (w/b)    retrained      next level     step time
# --------------------------------------------------------------------------------------------------------------
# 0       0                 [440, 25, 4]        (11100, 29)            None           75             None
#
# --------------------------------------------------------------------
# -- Learning has started...
# 	% problem dimension: 439
# 	% number of training samples: 16000
# 	% number of validation samples: 2000
# 	% learning rate: 0.03
# 	% mini-batch size: 10
# ...

# %%
net.t_data = net.prepare_data(x=dataset['x'], y=dataset['y'])
net.v_data = net.prepare_data(x=dataset['x_val'], y=dataset['y_val'])
test_data = net.prepare_data(x=dataset['x_test'], y=dataset['y_test'])
print 'full:', len(net.t_data), len(net.v_data), len(test_data)

#test_data_re = net_re.prepare_data(x=dataset_re['x_test'], y=dataset_re['y_test'])
#test_data_aa = net_aa.prepare_data(x=dataset_aa['x_test'], y=dataset_aa['y_test'])
# Out:
# --------------------------------------------------------------------------
# KeyError                                 Traceback (most recent call last)
# <ipython-input-5-6b8b579bb035> in <module>()
# ----> 1 net.t_data = net.prepare_data(x=dataset['x'], y=dataset['y'])
#       2 net.v_data = net.prepare_data(x=dataset['x_val'], y=dataset['y_val'])
#       3 test_data = net.prepare_data(x=dataset['x_test'], y=dataset['y_test'])
#       4 print 'full:', len(net.t_data), len(net.v_data), len(test_data)
#       5
#
# /usr/lib/python2.7/shelve.py in __getitem__(self, key)
#     119             value = self.cache[key]
#     120         except KeyError:
# --> 121             f = StringIO(self.dict[key])
#     122             value = Unpickler(f).load()
#     123             if self.writeback:
#
# /usr/lib/python2.7/bsddb/__init__.py in __getitem__(self, key)
#     268     def __getitem__(self, key):
#     269         self._checkOpen()
# ...

# %%
n_correct = 0
n_nr_correct_before = 0
n_nr_correct_after = 0
y_pred = list()
for i, (x, y) in enumerate(net.v_data):
    net_pred = net.predict(x=x)[0][0]
    y_true = net.labels[argmax(y)]
    
    if net_pred in ('A', 'a', 'Y'):
        if net_pred == y_true:
            n_nr_correct_before += 1
        net_pred = net2.predict(x=x)[0][0]
        if net_pred == y_true:
            n_nr_correct_after += 1
    '''
    elif net_pred == 'U' or net_pred == 'u':
        if net_pred == y_true:
            n_nr_correct_before += 1
        net_pred = net_uu.predict(x=x)[0][0]
        if net_pred == y_true:
            n_nr_correct_after += 1
    '''
    y_pred.append(net_pred)
    
    
    if y_true == net_pred:
        n_correct += 1

print float(n_correct)/len(net.v_data)
print n_nr_correct_before
print n_nr_correct_after
#print float(n_correct)/len(test_data)
# Out:
# 0.504736622944
# 592
# 621

# %%
#print test_data[0][0].shape, net.w[0].shape, net.b[0].shape

labels = [label for label in net.labels if label in dataset['y_val']]
#y_pred = [net.predict(x)[0][0] for x, y in net.v_data]
print 'Acc:', accuracy_score(y_true=dataset['y_val'], y_pred=y_pred)
cm = confusion_matrix(y_true=dataset['y_val'], y_pred=y_pred)
cm = cm.astype('float') / cm.sum(axis=1)[:, newaxis]
plt.imshow(cm, aspect='auto', interpolation='none', vmin=0, vmax=1)
plt.xticks(range(len(labels)), labels)
plt.yticks(range(len(labels)), labels)
plt.grid()
plt.colorbar()
plt.show()
print cm
for i in range(cm.shape[0]):
    print i, net.labels[i], sorted([(net.labels[j], round(cm[i, j], 2)) for j in range(cm.shape[1])], key=lambda x:x[1], reverse=True)[:5]
'''    
print '-----------------'
net.opt['tailoring'].analyse_cm(x_val=dataset['x_val'], y_val=dataset['y_val'], th=0.15)
'''
# Out:
# Acc: 0.504736622944
# [[ 0.606       0.          0.         ...,  0.          0.034       0.        ]
#  [ 0.002       0.65        0.006      ...,  0.02        0.          0.002     ]
#  [ 0.          0.          0.58835759 ...,  0.          0.          0.01039501]
#  ...,
#  [ 0.002       0.102       0.         ...,  0.554       0.01        0.004     ]
#  [ 0.006       0.002       0.         ...,  0.          0.478       0.008     ]
#  [ 0.          0.016       0.008      ...,  0.008       0.006       0.62      ]]
# 0 A [(u'A', 0.61), (u'a', 0.16), (u'E', 0.03), (u'y', 0.03), (u'Q', 0.02)]
# 1 C [(u'C', 0.65), (u'Q', 0.06), (u'S', 0.06), (u'T', 0.06), (u'c', 0.04)]
# 2 D [(u'D', 0.59), (u'b', 0.1), (u'd', 0.09), (u'j', 0.06), (u'T', 0.03)]
# 3 E [(u'E', 0.5), (u'e', 0.16), (u'a', 0.07), (u'r', 0.06), (u'A', 0.05)]
# 4 F [(u'y', 0.32), (u'F', 0.2), (u'e', 0.18), (u'v', 0.08), (u'N', 0.06)]
# 5 I [(u'I', 0.64), (u'i', 0.1), (u'j', 0.08), (u'N', 0.04), (u'J', 0.02)]
# ...

# %%
# Delete connections to selected phonemes
for ph_del in ('a', 'A'):
    net.w_is[1][net.labels.index(ph_del),:] = 0
    net.w[1][net.labels.index(ph_del),:] = 0
    net.b_is[1][net.labels.index(ph_del)] = 0
    net.b[1][net.labels.index(ph_del)] = 0

# %%
# Merge nets
tmp_1 = net.w[1].copy()
z_1 = zeros(shape=(net.w[1].shape[0], net_sz.structure[1]))
z_1[net.labels.index('r'),:] = net_sz.w[1][0]
z_1[net.labels.index('e'),:] = net_sz.w[1][1]
net.w[1] = concatenate((tmp_1, z_1), axis=1)
net.b[1][net.labels.index('r')] = net_sz.b[1][0]
net.b[1][net.labels.index('e')] = net_sz.b[1][1]

used_features_new = [(i, ff) for i, ff in enumerate(sorted(unique([f[1] for f in net.used_features]+[f[1] for f in net_sz.used_features])))]
features = [f[1] for f in used_features_new]
w_0 = zeros(shape=(net.structure[1]+net_sz.structure[1], len(used_features_new)))
b_0 = zeros(shape=(net.structure[1]+net_sz.structure[1], 1))
for row in range(net.w[0].shape[0]):
    for col in range(net.w[0].shape[1]):
        w_0[row,features.index(net.used_features[col][1])] = net.w[0][row,col]
    b_0[row] = net.b[0][row]
        
for row in range(net_sz.w[0].shape[0]):
    for col in range(net_sz.w[0].shape[1]):
        w_0[net.w[0].shape[0]+row,features.index(net_sz.used_features[col][1])] = net_sz.w[0][row,col]
    b_0[net.w[0].shape[0]+row] = net_sz.b[0][row]

net.used_features = used_features_new
net.w[0] = w_0
net.b[0] = b_0

net.structure = [net.w[0].shape[1]]+[w.shape[0] for w in net.w]
    
print w_0.shape, len(features), net.structure, net_sz.structure
# Out:
# (57, 440) 440 [440, 57, 40] [440, 7, 2]

# %%
net.dump('../examples/speech/net_speech_aasz_tailored_sz.net')
# Out:
# --------------------------------------------------------------------
# -- Net dumped as ../examples/speech/net_speech_aasz_tailored_sz.net
